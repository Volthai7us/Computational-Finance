# %% [markdown]
# ## Import libraries

# %%
import sys

sys.path.append('../src')
from utils import load_data, check_missing_values, plot_close_price, plot_feature_histograms, plot_price_by_time, plot_correlation_heatmap

# %% [markdown]
# ## Load data

# %%
path='../data/raw/1hour.csv'
df = load_data(path)
df.head()
# Out:
#             open_time  open_price  high_price  low_price  close_price
# 0 2017-08-17 04:00:00      301.13      302.57      298.0       301.61  \
# 1 2017-08-17 05:00:00      301.61      303.28      300.0       303.10
# 2 2017-08-17 06:00:00      302.40      304.44      301.9       302.68
# 3 2017-08-17 07:00:00      302.68      307.96      302.6       307.96
# 4 2017-08-17 08:00:00      307.95      309.97      307.0       308.62
#
#       volume              close_time  close_day  close_dayofweek  close_month
# 0  125.66877 2017-08-17 04:59:59.999         17                3            8  \
# 1  377.67246 2017-08-17 05:59:59.999         17                3            8
# 2  303.86672 2017-08-17 06:59:59.999         17                3            8
# 3  754.74510 2017-08-17 07:59:59.999         17                3            8
# 4  150.75029 2017-08-17 08:59:59.999         17                3            8
#
#    close_quarter  close_year
# 0              3        2017
# ...

# %% [markdown]
# ## Null or missing values control

# %%
check_missing_values(df)
# Out:
# Missing values in DataFrame: 0
# Missing values in each column: open_time          0
# open_price         0
# high_price         0
# low_price          0
# close_price        0
# volume             0
# close_time         0
# close_day          0
# close_dayofweek    0
# close_month        0
# close_quarter      0
# close_year         0
# dtype: int64
# Missing values in each row: 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 49149    0
# 49150    0
# 49151    0
# 49152    0
# 49153    0
# Length: 49154, dtype: int64

# %% [markdown]
# ## Visualize the close price of the Ethereum

# %%
plot_close_price(df)

# %%
plot_feature_histograms(df)

# %%
plot_price_by_time(df)

# %%
plot_correlation_heatmap(df, correlation_threshold=0.3)
